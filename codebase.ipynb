# %% [markdown]
# # **1. Setup & Library Imports**

# %%
import os
import math
import torch
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch import nn
from PIL import Image
from tqdm import tqdm
from diffusers import AutoencoderKL
from torch.nn import functional as F
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from transformers import CLIPTokenizer, CLIPTextModel
import torch.optim.lr_scheduler as lr_scheduler
from torch.amp import GradScaler, autocast

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)
    print(f"Seed set to {seed}")

set_seed()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# Seed set to 42
# cuda

# %%
# Download emoji dataset
# https://drive.google.com/file/d/15Z_F4Dwgb3NLqEGnVMUEJqyxXgW7Gx-h/view?usp=sharing
# !gdown 15Z_F4Dwgb3NLqEGnVMUEJqyxXgW7Gx-h
# !unzip blobs_crawled_data.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=15Z_F4Dwgb3NLqEGnVMUEJqyxXgW7Gx-h
# From (redirected): https://drive.google.com/uc?id=15Z_F4Dwgb3NLqEGnVMUEJqyxXgW7Gx-h&confirm=t&uuid=36ea8036-01ad-4714-a78c-b7a22ebead22
# To: /content/blobs_crawled_data.zip
# 100% 12.5M/12.5M [00:00<00:00, 54.0MB/s]
# Archive:  blobs_crawled_data.zip
#    creating: blobs_crawled_data/
#   inflating: blobs_crawled_data/metadata.csv
#    creating: blobs_crawled_data/images/
#  extracting: blobs_crawled_data/images/Blobs_0002712.jpg
#   inflating: blobs_crawled_data/images/Blobs_0003414.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006860.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000636.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001219.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005969.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007068.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000014.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003213.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005203.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003097.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018822.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004159.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000326.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013080.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001425.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013193.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010833.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013587.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013492.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000041.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018162.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003819.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001851.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000148.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000018.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009507.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008949.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004857.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004014.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009477.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015724.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007371.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004553.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001423.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013445.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001300.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001087.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005497.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004705.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003361.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015708.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006641.jpg
#   inflating: blobs_crawled_data/images/Blobs_0003905.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004974.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013295.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002050.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018179.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002223.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000208.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006038.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018422.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008345.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000996.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016952.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014045.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001572.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007233.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010055.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018866.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014594.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007284.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007716.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002897.jpg
#   inflating: blobs_crawled_data/images/Blobs_0015420.jpg
#   inflating: blobs_crawled_data/images/Blobs_0016960.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002840.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011913.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004121.jpg
#   inflating: blobs_crawled_data/images/Blobs_0017664.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003928.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000648.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000346.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017491.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005363.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005827.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001982.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014131.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002408.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015380.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000116.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002406.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007597.jpg
#   inflating: blobs_crawled_data/images/Blobs_0011349.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006789.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000750.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000859.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007074.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013215.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000040.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011421.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000942.jpg
#   inflating: blobs_crawled_data/images/Blobs_0005502.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001074.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013833.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001209.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002896.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017029.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006131.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017501.jpg
#   inflating: blobs_crawled_data/images/Blobs_0003927.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004522.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009489.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013434.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000560.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001484.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002657.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010845.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004624.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017571.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000688.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002412.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001197.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009974.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008203.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000154.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002906.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003158.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000886.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019741.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001123.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014720.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018269.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003260.jpg
#   inflating: blobs_crawled_data/images/Blobs_0018454.jpg
#   inflating: blobs_crawled_data/images/Blobs_0016864.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002257.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001498.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000904.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001412.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000606.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001631.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017573.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000213.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013736.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006873.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010289.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004968.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000530.jpg
#   inflating: blobs_crawled_data/images/Blobs_0017421.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000448.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010984.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004933.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014969.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004167.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001422.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017024.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007527.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001768.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012849.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000272.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001200.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001236.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013210.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002996.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015850.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019071.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000046.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004662.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001388.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013129.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004091.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004022.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017300.jpg
#   inflating: blobs_crawled_data/images/Blobs_0011328.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001932.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008286.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000241.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014929.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005957.jpg
#   inflating: blobs_crawled_data/images/Blobs_0006104.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005727.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000646.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001588.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000854.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018882.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010839.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018228.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017856.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009990.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000210.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002987.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015843.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001434.jpg
#   inflating: blobs_crawled_data/images/Blobs_0019255.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001942.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017958.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004118.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002999.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010461.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001559.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018969.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019671.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011912.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002055.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001255.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005789.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015147.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001968.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000182.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010286.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013039.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004782.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003061.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004285.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000538.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019070.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009766.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003369.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004397.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002360.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000075.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012142.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001547.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000919.jpg
#   inflating: blobs_crawled_data/images/Blobs_0005711.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013108.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000294.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007639.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000629.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004631.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008448.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004976.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005828.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001089.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012591.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010238.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019063.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000376.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003786.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001335.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000200.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019555.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003461.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002362.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000062.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018742.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015151.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003580.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010195.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000822.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014541.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013687.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001453.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001021.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000985.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018418.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000195.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006655.jpg
#   inflating: blobs_crawled_data/images/Blobs_0003343.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012450.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006351.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018913.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000078.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000955.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001369.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015492.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002095.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009970.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000590.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007530.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000836.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004517.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013520.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013167.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000686.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002195.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000399.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001970.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012764.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006859.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017402.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004498.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001139.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009644.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018048.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008450.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017563.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000292.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001478.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017042.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008195.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002255.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019870.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017322.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001443.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000355.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004697.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011123.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011013.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000051.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006547.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000303.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002663.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018396.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009030.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008997.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012457.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013278.jpg
#   inflating: blobs_crawled_data/images/Blobs_0002371.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016723.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009589.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007581.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012204.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011128.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012947.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004310.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002604.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000197.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004251.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010495.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018405.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001067.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017178.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000850.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001100.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002557.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016047.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001590.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006854.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017487.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006807.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017004.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002564.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000138.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000901.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001062.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016297.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002151.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000525.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001984.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003752.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001620.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006522.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011092.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001971.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000284.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001624.jpg
#   inflating: blobs_crawled_data/images/Blobs_0017375.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019625.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000724.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013292.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000533.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004363.jpg
#   inflating: blobs_crawled_data/images/Blobs_0003150.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017335.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009851.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001041.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016760.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012855.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015832.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000539.jpg
#   inflating: blobs_crawled_data/images/Blobs_0013171.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002083.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006111.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007552.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006040.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012435.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006047.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007620.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000803.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000601.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015778.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017317.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000744.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000300.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015794.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001550.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004011.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017261.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003439.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012456.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003878.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015572.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001095.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000053.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002161.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000394.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001227.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000057.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002007.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002094.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013230.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000128.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018419.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015071.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014422.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000658.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004324.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017022.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006634.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000987.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009656.jpg
#   inflating: blobs_crawled_data/images/Blobs_0002503.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015170.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000404.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001130.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018518.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012350.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000936.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004237.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017401.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014047.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013695.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000367.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017465.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001879.jpg
#   inflating: blobs_crawled_data/images/Blobs_0013427.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002776.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002524.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000231.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001576.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003155.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002634.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008973.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000119.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012108.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003348.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019628.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001299.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014635.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008410.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000348.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004216.jpg
#   inflating: blobs_crawled_data/images/Blobs_0016774.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001302.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011085.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001303.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017666.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000729.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011922.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000251.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012637.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004495.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004009.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013575.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017326.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019871.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004010.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000107.jpg
#   inflating: blobs_crawled_data/images/Blobs_0014141.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000701.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000016.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015415.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003117.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000226.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013130.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002061.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000652.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000068.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017639.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018916.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003813.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016744.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000458.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002390.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009551.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019254.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007385.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000268.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004502.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007179.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005965.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001680.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003099.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012808.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006088.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006288.jpg
#   inflating: blobs_crawled_data/images/Blobs_0002717.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006045.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017006.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001152.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000409.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016619.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010876.jpg
#   inflating: blobs_crawled_data/images/Blobs_0003092.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006578.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001070.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000954.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009028.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004580.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000441.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015711.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003048.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014103.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016032.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002297.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004521.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012857.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012379.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007053.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013121.jpg
#   inflating: blobs_crawled_data/images/Blobs_0015570.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003964.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008921.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011711.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011899.jpg
#   inflating: blobs_crawled_data/images/Blobs_0017376.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000698.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017495.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001204.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000725.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001024.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004066.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015719.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004832.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000150.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012685.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001732.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017992.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004937.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016871.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002455.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015741.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001280.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000582.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019202.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000745.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004711.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001107.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001161.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008873.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001108.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018342.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004766.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001494.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001651.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010054.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000959.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007662.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000449.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010841.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003215.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014397.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014395.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002668.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005170.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000408.jpg
#   inflating: blobs_crawled_data/images/Blobs_0017589.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000022.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000862.jpg
#   inflating: blobs_crawled_data/images/Blobs_0012853.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013732.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000930.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001622.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008912.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001307.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014110.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005942.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004008.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015032.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007061.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000461.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007497.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009731.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001720.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003017.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013763.jpg
#   inflating: blobs_crawled_data/images/Blobs_0017670.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010836.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000714.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001462.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006586.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002715.jpg
#   inflating: blobs_crawled_data/images/Blobs_0002550.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013053.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012844.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001878.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013429.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001056.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004715.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013708.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001150.jpg
#   inflating: blobs_crawled_data/images/Blobs_0012718.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005053.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014731.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017920.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000172.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005359.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012395.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004838.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009872.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000253.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000763.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000005.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005557.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013180.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019025.jpg
#   inflating: blobs_crawled_data/images/Blobs_0007609.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013727.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008277.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004746.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002625.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001288.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002697.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004752.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000693.jpg
#   inflating: blobs_crawled_data/images/Blobs_0009126.jpg
#   inflating: blobs_crawled_data/images/Blobs_0002060.jpg
#   inflating: blobs_crawled_data/images/Blobs_0002311.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000828.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013638.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000432.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001834.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019098.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010298.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019049.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013696.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001792.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000490.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004127.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013681.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000843.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017308.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000370.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018973.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012439.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000114.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017310.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005171.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009871.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007020.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000603.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000164.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019737.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008534.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007650.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003121.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011578.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015940.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001743.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019744.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015481.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001635.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007089.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012042.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013332.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000579.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002120.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000320.jpg
#   inflating: blobs_crawled_data/images/Blobs_0016916.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011708.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000807.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001493.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002649.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019033.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004628.jpg
#   inflating: blobs_crawled_data/images/Blobs_0012550.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019157.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011021.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014370.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000577.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000299.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001058.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000391.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013880.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015543.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003151.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001277.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000812.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008928.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000749.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000659.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000632.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004893.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012365.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017195.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003435.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017499.jpg
#   inflating: blobs_crawled_data/images/Blobs_0013304.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008190.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003803.jpg
#   inflating: blobs_crawled_data/images/Blobs_0014970.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004186.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000716.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001747.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015150.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008014.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000990.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001079.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016743.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002039.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004500.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007592.jpg
#   inflating: blobs_crawled_data/images/Blobs_0008716.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017668.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010843.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010522.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011709.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012465.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003086.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001324.jpg
#   inflating: blobs_crawled_data/images/Blobs_0006049.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000151.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000190.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001886.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000111.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001427.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016050.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000397.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015068.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006651.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004188.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017663.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001242.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000928.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005574.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010292.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004871.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001602.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000737.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000580.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001260.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000677.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003592.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000486.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000392.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001212.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009829.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012529.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004510.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012446.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013901.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003763.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013271.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004458.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003000.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000359.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001788.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000775.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007861.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010607.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003493.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002248.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003830.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001628.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012464.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018827.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000860.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001949.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000683.jpg
#   inflating: blobs_crawled_data/images/Blobs_0012734.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012371.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000545.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016220.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010604.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000427.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001530.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014643.jpg
#   inflating: blobs_crawled_data/images/Blobs_0009356.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009830.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001029.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001785.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015149.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002229.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000212.jpg
#   inflating: blobs_crawled_data/images/Blobs_0002124.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017954.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001125.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001232.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001354.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001314.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004868.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000149.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018883.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010021.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010852.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010914.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013213.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017552.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001310.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000607.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001035.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004020.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010307.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000243.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015567.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019217.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018128.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001773.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017836.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003043.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002101.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005737.jpg
#   inflating: blobs_crawled_data/images/Blobs_0013211.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006177.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017457.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015820.jpg
#   inflating: blobs_crawled_data/images/Blobs_0011025.jpg
#   inflating: blobs_crawled_data/images/Blobs_0017218.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004526.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000373.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002420.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017661.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009660.jpg
#   inflating: blobs_crawled_data/images/Blobs_0015421.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001534.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010068.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015739.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000167.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001160.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001658.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013595.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008745.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018449.jpg
# ...
#  extracting: blobs_crawled_data/images/Blobs_0016620.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007926.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001395.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013518.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004499.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001294.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007374.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001044.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004339.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001323.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011052.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017768.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004301.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001662.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000630.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007220.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017273.jpg
#   inflating: blobs_crawled_data/images/Blobs_0018826.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002946.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003940.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008525.jpg
#   inflating: blobs_crawled_data/images/Blobs_0012719.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000100.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018486.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018793.jpg
#   inflating: blobs_crawled_data/images/Blobs_0004017.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011878.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017156.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018043.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002789.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000645.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011781.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019308.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009146.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014878.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000971.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002493.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014149.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001570.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013607.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007711.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004692.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017570.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019523.jpg
#   inflating: blobs_crawled_data/images/Blobs_0019717.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000347.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001918.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005012.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011385.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000711.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001997.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001122.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012762.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001301.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018858.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005916.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016665.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001088.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017314.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005212.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002035.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004744.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018151.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004966.jpg
#   inflating: blobs_crawled_data/images/Blobs_0018971.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006554.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013334.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010521.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005266.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001078.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001849.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003346.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001912.jpg
#   inflating: blobs_crawled_data/images/Blobs_0005265.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000865.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001346.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011380.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019095.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004527.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018850.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009440.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016986.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016221.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004525.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009058.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007538.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010881.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017548.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001837.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000228.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006899.jpg
#   inflating: blobs_crawled_data/images/Blobs_0006206.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012590.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014769.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016326.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009795.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004703.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000553.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001529.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004351.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010517.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010450.jpg
#   inflating: blobs_crawled_data/images/Blobs_0009425.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006779.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004853.jpg
#   inflating: blobs_crawled_data/images/Blobs_0002247.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018719.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001032.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002965.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017332.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013900.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012899.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003327.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007906.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010124.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001174.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001772.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006207.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018911.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013219.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017591.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001861.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000112.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007150.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000410.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012845.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006852.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011923.jpg
#   inflating: blobs_crawled_data/images/Blobs_0018877.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003342.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002033.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013488.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014237.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014949.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015903.jpg
#   inflating: blobs_crawled_data/images/Blobs_0013588.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000514.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003303.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018868.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001919.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017557.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002045.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019261.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016149.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000569.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018845.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009918.jpg
#   inflating: blobs_crawled_data/images/Blobs_0000358.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005017.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001779.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014759.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000584.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007602.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018285.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013905.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003417.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001170.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000169.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010987.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013426.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006808.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007821.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017568.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008224.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013689.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017551.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000055.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001115.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000089.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006596.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018185.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014080.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008763.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002566.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002797.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000575.jpg
#  extracting: blobs_crawled_data/images/Blobs_0010412.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000976.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019093.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006042.jpg
#   inflating: blobs_crawled_data/images/Blobs_0006799.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017197.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000064.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003573.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000504.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017010.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006543.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017790.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001155.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017405.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015145.jpg
#   inflating: blobs_crawled_data/images/Blobs_0016773.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000171.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000851.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008437.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014922.jpg
#   inflating: blobs_crawled_data/images/Blobs_0013911.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000770.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017624.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015854.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001611.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002900.jpg
#   inflating: blobs_crawled_data/images/Blobs_0005267.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013694.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000640.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000969.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000951.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001410.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000780.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001459.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000218.jpg
#  extracting: blobs_crawled_data/images/Blobs_0008192.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004039.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019073.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018813.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017490.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000503.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017955.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006108.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000134.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001216.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017520.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001235.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005206.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019065.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001938.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000984.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019585.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002236.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002037.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017659.jpg
#  extracting: blobs_crawled_data/images/Blobs_0001057.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015511.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000494.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011985.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016987.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015816.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003026.jpg
#  extracting: blobs_crawled_data/images/Blobs_0017822.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002071.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011194.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004696.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013703.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002019.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015140.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009962.jpg
#   inflating: blobs_crawled_data/images/Blobs_0017622.jpg
#  extracting: blobs_crawled_data/images/Blobs_0000198.jpg
#  extracting: blobs_crawled_data/images/Blobs_0016447.jpg
#   inflating: blobs_crawled_data/images/Blobs_0010855.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013066.jpg
#  extracting: blobs_crawled_data/images/Blobs_0015742.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002098.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018841.jpg
#   inflating: blobs_crawled_data/images/Blobs_0008199.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018047.jpg
#  extracting: blobs_crawled_data/images/Blobs_0007336.jpg
#  extracting: blobs_crawled_data/images/Blobs_0006920.jpg
#  extracting: blobs_crawled_data/images/Blobs_0005119.jpg
#  extracting: blobs_crawled_data/images/Blobs_0019847.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003103.jpg
#  extracting: blobs_crawled_data/images/Blobs_0018234.jpg
#  extracting: blobs_crawled_data/images/Blobs_0002176.jpg
#  extracting: blobs_crawled_data/images/Blobs_0009867.jpg
#  extracting: blobs_crawled_data/images/Blobs_0013403.jpg
#  extracting: blobs_crawled_data/images/Blobs_0014539.jpg
#  extracting: blobs_crawled_data/images/Blobs_0003801.jpg
#  extracting: blobs_crawled_data/images/Blobs_0012707.jpg
#   inflating: blobs_crawled_data/images/Blobs_0001823.jpg
#  extracting: blobs_crawled_data/images/Blobs_0004043.jpg
#  extracting: blobs_crawled_data/images/Blobs_0011958.jpg

# %% [markdown]
# # **2. Attention Mechanism**

# %% [markdown]
# ## 2.1 Self-Attention

# %%
class SelfAttention(nn.Module):
    def __init__(self, num_attn_heads, hidden_dim, in_proj_bias=True, out_proj_bias=True):
        super().__init__()
        self.num_heads = num_attn_heads
        self.head_size = hidden_dim // num_attn_heads

        self.qkv_proj = nn.Linear(hidden_dim, 3 * hidden_dim, bias=in_proj_bias)
        self.output_proj = nn.Linear(hidden_dim, hidden_dim, bias=out_proj_bias)

    def forward(self, features, use_causal_mask=False):
        b, s, d = features.shape

        qkv_combined = self.qkv_proj(features)
        q_mat, k_mat, v_mat = torch.chunk(qkv_combined, 3, dim=-1)

        q_mat = q_mat.view(b, s, self.num_heads, self.head_size).permute(0, 2, 1, 3)
        k_mat = k_mat.view(b, s, self.num_heads, self.head_size).permute(0, 2, 1, 3)
        v_mat = v_mat.view(b, s, self.num_heads, self.head_size).permute(0, 2, 1, 3)

        qk = torch.matmul(q_mat, k_mat.transpose(-2, -1))
        sqrt_qk = qk / math.sqrt(self.head_size)

        if use_causal_mask:
            causal_mask = torch.triu(torch.ones_like(sqrt_qk, dtype=torch.bool), diagonal=1)
            sqrt_qk = sqrt_qk.masked_fill(causal_mask, -torch.inf)

        attn_weights = torch.softmax(sqrt_qk, dim=-1)
        attn_values = torch.matmul(attn_weights, v_mat)

        attn_values = attn_values.permute(0, 2, 1, 3).contiguous()
        attn_values = attn_values.view(b, s, d)

        final_output = self.output_proj(attn_values)
        return final_output

# %% [markdown]
# ## 2.2 Cross-Attention

# %%
class CrossAttention(nn.Module):
    def __init__(self, num_attn_heads, query_dim, context_dim, in_proj_bias=True, out_proj_bias=True):
        super().__init__()
        self.num_heads = num_attn_heads
        self.head_size = query_dim // num_attn_heads

        self.query_map = nn.Linear(query_dim, query_dim, bias=in_proj_bias)
        self.key_map = nn.Linear(context_dim, query_dim, bias=in_proj_bias)
        self.value_map = nn.Linear(context_dim, query_dim, bias=in_proj_bias)

        self.output_map = nn.Linear(query_dim, query_dim, bias=out_proj_bias)

    def forward(self, query_input, context_input):
        b_q, s_q, d_q = query_input.shape
        _, s_kv, _ = context_input.shape

        q_mat = self.query_map(query_input)
        k_mat = self.key_map(context_input)
        v_mat = self.value_map(context_input)

        q_mat = q_mat.view(b_q, s_q, self.num_heads, self.head_size).permute(0, 2, 1, 3)
        k_mat = k_mat.view(b_q, s_kv, self.num_heads, self.head_size).permute(0, 2, 1, 3)
        v_mat = v_mat.view(b_q, s_kv, self.num_heads, self.head_size).permute(0, 2, 1, 3)

        qk = torch.matmul(q_mat, k_mat.transpose(-2, -1))
        sqrt_qk = qk / math.sqrt(self.head_size)
        attn_weights = torch.softmax(sqrt_qk, dim=-1)

        attn_values = torch.matmul(attn_weights, v_mat)
        attn_values = attn_values.permute(0, 2, 1, 3).contiguous()
        attn_values = attn_values.view(b_q, s_q, d_q)

        final_output = self.output_map(attn_values)
        return final_output

# %% [markdown]
# # **3. Stable Diffusion**

# %% [markdown]
# ## **3.1 DDPM - Denoising Diffusion Probabilistic Model**

# %%
class DDPMScheduler:
    def __init__(
        self,
        random_generator,
        train_timesteps=1000,
        diffusion_beta_start=0.00085,
        diffusion_beta_end=0.012
    ):

        self.betas = torch.linspace(
            diffusion_beta_start ** 0.5, diffusion_beta_end ** 0.5, train_timesteps,
            dtype=torch.float32) ** 2
        self.alphas = 1.0 - self.betas
        self.alphas_cumulative_product = torch.cumprod(self.alphas, dim=0)
        self.one_val = torch.tensor(1.0)
        self.prng_generator = random_generator
        self.total_train_timesteps = train_timesteps
        self.schedule_timesteps = torch.from_numpy(np.arange(0, train_timesteps)[::-1].copy())

    def set_steps(self, num_sampling_steps=50):
        self.num_sampling_steps = num_sampling_steps
        step_scaling_factor = self.total_train_timesteps // self.num_sampling_steps
        timesteps_for_sampling = (
            np.arange(0, num_sampling_steps) * step_scaling_factor
        ).round()[::-1].copy().astype(np.int64)
        self.schedule_timesteps = torch.from_numpy(timesteps_for_sampling)

    def _get_prior_timestep(self, current_timestep):
        previous_t = current_timestep - self.total_train_timesteps // self.num_sampling_steps
        return previous_t

    def _calculate_variance(self, timestep):
        prev_t = self._get_prior_timestep(timestep)
        alpha_cumprod_t = self.alphas_cumulative_product[timestep]
        alpha_cumprod_t_prev = self.alphas_cumulative_product[prev_t] if prev_t >= 0 else self.one_val
        beta_t_current = 1 - alpha_cumprod_t / alpha_cumprod_t_prev
        variance_value = (1 - alpha_cumprod_t_prev) / (1 - alpha_cumprod_t) * beta_t_current
        variance_value = torch.clamp(variance_value, min=1e-20)
        return variance_value

    def adjust_strength(self, strength_level=1):
        initial_step_index = self.num_sampling_steps - int(self.num_sampling_steps * strength_level)
        self.schedule_timesteps = self.schedule_timesteps[initial_step_index:]
        self.start_sampling_step = initial_step_index # Lưu lại bước bắt đầu

    def step(self, current_t, current_latents, model_prediction):
        t = current_t
        prev_t = self._get_prior_timestep(t)

        alpha_cumprod_t = self.alphas_cumulative_product[t]
        alpha_cumprod_t_prev = self.alphas_cumulative_product[prev_t] if prev_t >= 0 else self.one_val
        beta_cumprod_t = 1 - alpha_cumprod_t
        beta_cumprod_t_prev = 1 - alpha_cumprod_t_prev
        alpha_t_current = alpha_cumprod_t / alpha_cumprod_t_prev
        beta_t_current = 1 - alpha_t_current

        predicted_original = (current_latents - beta_cumprod_t ** 0.5 * model_prediction) / alpha_cumprod_t ** 0.5

        original_coeff = (alpha_cumprod_t_prev ** 0.5 * beta_t_current) / beta_cumprod_t
        current_coeff = alpha_t_current ** 0.5 * beta_cumprod_t_prev / beta_cumprod_t

        predicted_prior_mean = original_coeff * predicted_original + current_coeff * current_latents

        variance_term = 0
        if t > 0:
            target_device = model_prediction.device
            noise_component = torch.randn(
                model_prediction.shape,
                generator=self.prng_generator,
                device=target_device,
                dtype=model_prediction.dtype
            )
            variance_term = (self._calculate_variance(t) ** 0.5) * noise_component

        predicted_prior_sample = predicted_prior_mean + variance_term
        return predicted_prior_sample

    def add_noise(self, initial_samples, noise_timesteps):
        alphas_cumprod = self.alphas_cumulative_product.to(
            device=initial_samples.device,
            dtype=initial_samples.dtype
        )
        noise_timesteps = noise_timesteps.to(initial_samples.device)
        sqrt_alpha_cumprod = alphas_cumprod[noise_timesteps] ** 0.5
        sqrt_alpha_cumprod = sqrt_alpha_cumprod.view(
            sqrt_alpha_cumprod.shape[0], *([1] * (initial_samples.ndim - 1))
        )
        sqrt_one_minus_alpha_cumprod = (1 - alphas_cumprod[noise_timesteps]) ** 0.5
        sqrt_one_minus_alpha_cumprod = sqrt_one_minus_alpha_cumprod.view(
            sqrt_one_minus_alpha_cumprod.shape[0], *([1] * (initial_samples.ndim - 1))
        )
        random_noise = torch.randn(
            initial_samples.shape, generator=self.prng_generator,
            device=initial_samples.device, dtype=initial_samples.dtype
        )
        noisy_result = sqrt_alpha_cumprod * initial_samples + sqrt_one_minus_alpha_cumprod * random_noise
        return noisy_result, random_noise

# %% [markdown]
# ## **3.2 UNet Architecture**

# %% [markdown]
# ### 3.2.1 Residual Block

# %%
class UNET_ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, time_dim=1280):
        super().__init__()
        self.gn_feature = nn.GroupNorm(32, in_channels)
        self.conv_feature = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.time_embedding_proj = nn.Linear(time_dim, out_channels)

        self.gn_merged = nn.GroupNorm(32, out_channels)
        self.conv_merged = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)

        if in_channels == out_channels:
            self.residual_connection = nn.Identity()
        else:
            self.residual_connection = nn.Conv2d(in_channels, out_channels, kernel_size=1, padding=0)

    def forward(self, input_feature, time_emb):
        residual = input_feature

        h = self.gn_feature(input_feature)
        h = F.silu(h)
        h = self.conv_feature(h)

        time_emb_processed = F.silu(time_emb)
        time_emb_projected = self.time_embedding_proj(time_emb_processed)
        time_emb_projected = time_emb_projected.unsqueeze(-1).unsqueeze(-1)

        merged_feature = h + time_emb_projected
        merged_feature = self.gn_merged(merged_feature)
        merged_feature = F.silu(merged_feature)
        merged_feature = self.conv_merged(merged_feature)

        output = merged_feature + self.residual_connection(residual)
        return output

# %% [markdown]
# ### 3.2.2 Attention Block

# %%
class UNET_AttentionBlock(nn.Module):
    def __init__(self, num_heads, head_dim, context_dim=512):
        super().__init__()
        embed_dim = num_heads * head_dim

        self.gn_in = nn.GroupNorm(32, embed_dim, eps=1e-6)
        self.proj_in = nn.Conv2d(embed_dim, embed_dim, kernel_size=1, padding=0)

        self.ln_1 = nn.LayerNorm(embed_dim)
        self.attn_1 = SelfAttention(num_heads, embed_dim, in_proj_bias=False)
        self.ln_2 = nn.LayerNorm(embed_dim)
        self.attn_2 = CrossAttention(num_heads, embed_dim, context_dim, in_proj_bias=False)
        self.ln_3 = nn.LayerNorm(embed_dim)

        self.ffn_geglu = nn.Linear(embed_dim, 4 * embed_dim * 2)
        self.ffn_out = nn.Linear(4 * embed_dim, embed_dim)
        self.proj_out = nn.Conv2d(embed_dim, embed_dim, kernel_size=1, padding=0)

    def forward(self, input_tensor, context_tensor):
        skip_connection = input_tensor

        B, C, H, W = input_tensor.shape
        HW = H * W

        h = self.gn_in(input_tensor)
        h = self.proj_in(h)
        h = h.view(B, C, HW).transpose(-1, -2)

        attn1_skip = h
        h = self.ln_1(h)
        h = self.attn_1(h)
        h = h + attn1_skip

        attn2_skip = h
        h = self.ln_2(h)
        h = self.attn_2(h, context_tensor)
        h = h + attn2_skip

        ffn_skip = h
        h = self.ln_3(h)
        intermediate, gate = self.ffn_geglu(h).chunk(2, dim=-1)
        h = intermediate * F.gelu(gate)
        h = self.ffn_out(h)
        h = h + ffn_skip

        h = h.transpose(-1, -2).view(B, C, H, W)
        output = self.proj_out(h) + skip_connection
        return output

# %%
class Upsample(nn.Module):
    def __init__(self, num_channels):
        super().__init__()
        self.conv = nn.Conv2d(num_channels, num_channels, kernel_size=3, padding=1)

    def forward(self, feature_map):
        x = F.interpolate(feature_map, scale_factor=2, mode='nearest')
        x = self.conv(x)
        return x


class SwitchSequential(nn.Sequential):
    def forward(self, x, guidance_context, time_embedding):
        for module_instance in self:
            if isinstance(module_instance, UNET_AttentionBlock):
                x = module_instance(x, guidance_context)
            elif isinstance(module_instance, UNET_ResidualBlock):
                x = module_instance(x, time_embedding)
            else:
                x = module_instance(x)
        return x


class TimeEmbedding(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.proj1 = nn.Linear(n_embd, 4 * n_embd)
        self.proj2 = nn.Linear(4 * n_embd, 4 * n_embd)

    def forward(self, x):
        x = self.proj1(x)
        x = F.silu(x)
        x = self.proj2(x)
        return x

# %%
class UNET(nn.Module):
    def __init__(self, h_dim, n_head):
        super().__init__()

        self.down_blocks = nn.ModuleList([
            SwitchSequential(nn.Conv2d(4, h_dim, kernel_size=3, padding=1)),
            SwitchSequential(
                UNET_ResidualBlock(h_dim, h_dim),
                UNET_AttentionBlock(n_head, (h_dim)//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(h_dim, h_dim),
                UNET_AttentionBlock(n_head, (h_dim)//n_head)
            ),
            SwitchSequential(nn.Conv2d(h_dim, h_dim, kernel_size=3, stride=2, padding=1)),
            SwitchSequential(
                UNET_ResidualBlock(h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head)
            ),
            SwitchSequential(nn.Conv2d(2*h_dim, 2*h_dim, kernel_size=3, stride=2, padding=1)),
            SwitchSequential(UNET_ResidualBlock(2*h_dim, 4*h_dim)),
            SwitchSequential(UNET_ResidualBlock(4*h_dim, 4*h_dim)),
        ])

        self.mid_block = SwitchSequential(
            UNET_ResidualBlock(4*h_dim, 4*h_dim),
            UNET_AttentionBlock(n_head, (4*h_dim)//n_head),
            UNET_ResidualBlock(4*h_dim, 4*h_dim),
        )

        self.up_blocks = nn.ModuleList([
            SwitchSequential(UNET_ResidualBlock(4*h_dim + 4*h_dim, 4*h_dim)),
            SwitchSequential(UNET_ResidualBlock(4*h_dim + 4*h_dim, 4*h_dim)),
            SwitchSequential(
                UNET_ResidualBlock(4*h_dim + 2*h_dim, 4*h_dim),
                Upsample(4*h_dim)
            ),
            SwitchSequential(
                UNET_ResidualBlock(4*h_dim + 2*h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(4*h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim + h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head),
                Upsample(2*h_dim)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim + h_dim, h_dim),
                UNET_AttentionBlock(n_head, h_dim//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim, h_dim),
                UNET_AttentionBlock(n_head, h_dim//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim, h_dim),
                UNET_AttentionBlock(n_head, h_dim//n_head)
            ),
        ])

    def forward(self, latent_input, context_embedding, time_embedding):
        down_block_residuals = []
        current_feature_map = latent_input

        for block in self.down_blocks:
            current_feature_map = block(
                current_feature_map,
                context_embedding,
                time_embedding
            )
            down_block_residuals.append(current_feature_map)

        current_feature_map = self.mid_block(
            current_feature_map,
            context_embedding,
            time_embedding
        )

        for block in self.up_blocks:
            residual = down_block_residuals.pop()
            current_feature_map = torch.cat((current_feature_map, residual), dim=1)
            current_feature_map = block(
                current_feature_map,
                context_embedding,
                time_embedding
            )

        return current_feature_map


class UNETOutputLayer(nn.Module):
    def __init__(self, input_channels, output_channels):
        super().__init__()
        self.final_groupnorm = nn.GroupNorm(32, input_channels)
        self.final_conv = nn.Conv2d(input_channels, output_channels, kernel_size=3, padding=1)

    def forward(self, feature_map):
        norm_map = self.final_groupnorm(feature_map)
        activated_map = F.silu(norm_map)
        output_map = self.final_conv(activated_map)

        return output_map

# %% [markdown]
# ## **3.3 Timestep Handling**

# %%
def embed_a_timestep(timestep, embedding_dim=320):
    half_dim = embedding_dim // 2
    freqs = torch.exp(-math.log(10000) *
                      torch.arange(start=0, end=half_dim, dtype=torch.float32) /
                      half_dim)
    x = torch.tensor([timestep], dtype=torch.float32)[:, None] * freqs[None]
    return torch.cat([torch.cos(x), torch.sin(x)], dim=-1)

def embed_timesteps(timesteps, embedding_dim=320):
    half_dim = embedding_dim // 2
    freqs = torch.exp(-math.log(10000) *
                      torch.arange(half_dim, dtype=torch.float32) /
                      half_dim).to(device=timesteps.device)
    args = timesteps[:, None].float() * freqs[None, :]
    return torch.cat([torch.cos(args), torch.sin(args)], dim=-1)

# %% [markdown]
# ## **3.4 Diffusion Process**

# %%
class Diffusion(nn.Module):
    def __init__(self, h_dim=128, n_head=4):
        super().__init__()
        self.time_embedding = TimeEmbedding(320)
        self.unet = UNET(h_dim, n_head)
        self.unet_output = UNETOutputLayer(h_dim, 4)

    @torch.autocast(
        device_type='cuda', dtype=torch.float16,
        enabled=True, cache_enabled=True
    )
    def forward(self, latent, context, time):
        time = self.time_embedding(time)
        output = self.unet(latent, context, time)
        output = self.unet_output(output)
        return output

# %% [markdown]
# ## **3.5 CLIP - Contrastive Language-Image Pre-Training**

# %%
class CLIPTextEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        CLIP_id = "openai/clip-vit-base-patch32"
        self.tokenizer = CLIPTokenizer.from_pretrained(CLIP_id)
        self.text_encoder = CLIPTextModel.from_pretrained(CLIP_id)
        self.device = "cuda" if torch.cuda.is_available() else "cpu"

        for param in self.text_encoder.parameters():
            param.requires_grad = False

        self.text_encoder.eval()
        self.text_encoder.to(self.device)

    def forward(self, prompts):
        inputs = self.tokenizer(
            prompts,
            padding="max_length",
            truncation=True,
            max_length=self.text_encoder.config.max_position_embeddings,
            return_tensors="pt"
        )
        input_ids = inputs.input_ids.to(self.device)
        attention_mask = inputs.attention_mask.to(self.device)

        with torch.no_grad():
            text_encoder_output = self.text_encoder(
                input_ids=input_ids,
                attention_mask=attention_mask
            )
        last_hidden_states = text_encoder_output.last_hidden_state

        return last_hidden_states

# %% [markdown]
# ## **3.6. VAE - Variational Autoencoder**

# %%
VAE_id = "stabilityai/sd-vae-ft-mse"
vae = AutoencoderKL.from_pretrained(VAE_id)
vae.requires_grad_(False)
vae.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# AutoencoderKL(
#   (encoder): Encoder(
#     (conv_in): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (down_blocks): ModuleList(
#       (0): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0-1): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (1): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (2): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (3): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0-1): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#       )
#     )
#     (mid_block): UNetMidBlock2D(
#       (attentions): ModuleList(
#         (0): Attention(
#           (group_norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (to_q): Linear(in_features=512, out_features=512, bias=True)
#           (to_k): Linear(in_features=512, out_features=512, bias=True)
#           (to_v): Linear(in_features=512, out_features=512, bias=True)
#           (to_out): ModuleList(
#             (0): Linear(in_features=512, out_features=512, bias=True)
#             (1): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#     )
#     (conv_norm_out): GroupNorm(32, 512, eps=1e-06, affine=True)
#     (conv_act): SiLU()
#     (conv_out): Conv2d(512, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (decoder): Decoder(
#     (conv_in): Conv2d(4, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (up_blocks): ModuleList(
#       (0-1): 2 x UpDecoderBlock2D(
#         (resnets): ModuleList(
#           (0-2): 3 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (upsamplers): ModuleList(
#           (0): Upsample2D(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (2): UpDecoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (upsamplers): ModuleList(
#           (0): Upsample2D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (3): UpDecoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#       )
#     )
#     (mid_block): UNetMidBlock2D(
#       (attentions): ModuleList(
#         (0): Attention(
#           (group_norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (to_q): Linear(in_features=512, out_features=512, bias=True)
#           (to_k): Linear(in_features=512, out_features=512, bias=True)
#           (to_v): Linear(in_features=512, out_features=512, bias=True)
#           (to_out): ModuleList(
#             (0): Linear(in_features=512, out_features=512, bias=True)
#             (1): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#     )
#     (conv_norm_out): GroupNorm(32, 128, eps=1e-06, affine=True)
#     (conv_act): SiLU()
#     (conv_out): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (quant_conv): Conv2d(8, 8, kernel_size=(1, 1), stride=(1, 1))
#   (post_quant_conv): Conv2d(4, 4, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# # **4. Utility Functions**

# %%
def show_images(images, title="", titles=[]):
    plt.figure(figsize=(8, 8))
    for i in range(min(25, len(images))):
        plt.subplot(5, 5, i+1)
        img = images[i].permute(1, 2, 0).cpu().numpy()
        plt.imshow(img)
        if titles:
            plt.title(titles[i])
        plt.axis('off')
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()


def rescale(value, in_range, out_range, clamp=False):
    in_min, in_max = in_range
    out_min, out_max = out_range

    in_span = in_max - in_min
    out_span = out_max - out_min

    scaled_value = (value - in_min) / (in_span + 1e-8)
    rescaled_value = out_min + (scaled_value * out_span)

    if clamp:
        rescaled_value = torch.clamp(
            rescaled_value,
            out_min, out_max
        )

    return rescaled_value

# %% [markdown]
# # **5. Dataset Preparation**

# %%
WIDTH, HEIGHT = 32, 32
batch_size = 32

class EmojiDataset(Dataset):
    def __init__(self, csv_files, image_folder, transform=None):
        self.dataframe = pd.concat([pd.read_csv(csv_file) for csv_file in csv_files])
        self.images_folder = image_folder
        self.dataframe['image_path'] = self.dataframe['file_name'].str.replace('\\', '/')
        self.image_paths = self.dataframe['image_path'].tolist()
        self.titles = self.dataframe['prompt'].tolist()
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        image_path = self.images_folder + '/' + self.image_paths[idx]
        title = self.titles[idx]
        title = title.replace('"', '').replace("'", '')
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, title

transform = transforms.Compose([
    transforms.Resize(
        (WIDTH, HEIGHT),
        interpolation=transforms.InterpolationMode.BICUBIC
    ),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

csv_files = ['/content/blobs_crawled_data/metadata.csv']
image_folder = '/content/blobs_crawled_data/images'

train_dataset = EmojiDataset(
    csv_files=csv_files,
    image_folder=image_folder,
    transform=transform
)
train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    persistent_workers=True
)

dataiter = iter(train_dataloader)
images, titles = next(dataiter)

print(f"Batch images shape: {images.shape}")

clipped_images = torch.clamp(images, 0, 1)
plt.figure(figsize=(8, 8))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(clipped_images[i].permute(1, 2, 0).numpy())
    print(titles[i])
    plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Batch images shape: torch.Size([32, 3, 32, 32])
# blobcat_Roll emoji with a round head, small black eyes, slightly open mouth, neutral expression, orange skin color, no action, with a white background.
# Blob_Nuzzle emoji with a round head, closed eyes, small mouth, content expression, yellow skin color, no action, with a white background.
# Pride Blob emoji with a round head, small black eyes, winking mouth, happy expression, yellow skin color, no action, with a white background.
# Blobhaj_Glare emoji with a rounded head, black oval eyes, small curved mouth, sad expression, white skin color, no action, with a white background.
# DNS BluePurpleBlob emoji with a round head, large circular eyes, slightly open mouth, neutral expression, blue-purple skin color, no action, with a light blue background.
# BlobDance emoji with a round head, small black eyes, smiling mouth, happy expression, black skin color, no action, with a black background.
# Blobbellsprout emoji with a round head, small round eyes, open mouth, surprised expression, yellow skin color, no action, with a white background.
# Hyperblob emoji with a round head, small black eyes, smiling mouth, happy expression, light blue skin color, no action, with a white background.
# ablobtoiletflush emoji with a round head, small black eyes, open mouth, surprised expression, yellow skin color, flushing action, with a white background.
# Blob Wave Reverse emoji with a rounded head, black dot eyes, orange oval mouth, surprised expression, yellow skin color, waving arm, with a white background.
# BlobCatHug emoji with a round head, black dot eyes, wide open mouth, surprised expression, yellow skin color, hugging action, with a white background.
# blobsweats emoji with a round head, large bulging eyes, small open mouth, surprised expression, yellow skin color, no action, with a white background.
# blobcatree emoji with a round head, small eyes, open mouth, angry expression, yellow skin color, no action, with a white background.
# Blob_Thinking emoji with a rounded head, small black eyes, raised eyebrows, wide open mouth, thinking expression, yellow skin color, no action, with a white background.
# Pink Blob emoji with a round head, small brown eyes, frowning mouth, angry expression, pink skin color, no action, with a pink background.
# pd_BlobFlushed emoji with a rounded head, large black eyes, open mouth showing teeth, surprised expression, yellow skin color, no action, with a white background.
# sa_XmasBlobKittySnow emoji with a round head, large round eyes, small mouth, surprised expression, white skin color, no action, with a white background.
# Blobsmile emoji with a rounded head, black dot eyes, curved smile mouth, happy expression, yellow skin color, no action, with a white background.
# Blob Cheer emoji with a round head, closed eyes, wide open mouth, joyful expression, yellow skin color, hands raised in the air, with a white background.
# Ablobflushed emoji with a round head, large round eyes, slightly open mouth, surprised expression, yellow skin color, no action, with a white background.
# 6191 blob happy peak emoji with a round head, black dot eyes, smiling mouth, happy expression, yellow skin color, no action, with a white background.
# Blobcat emoji with a round head, small black eyes, slightly open mouth, surprised expression, white skin color, no action, with a white background.
# blobpride emoji with a round head, two large white circles for eyes, a small curved line for a mouth, a happy expression, rainbow skin color, no action, with a white background.
# NellyBlob emoji with a round head, large black eyes, small mouth, neutral expression, light blue skin color, no action, with a light blue background.
# pd_BlobSmile emoji with a round head, closed black eyes, wide orange smile, happy expression, yellow skin color, no action, with a white background.

# %% [markdown]
# # **6. Model Training**

# %%
def train(diffusion, vae, text_encoder, scheduler,
          optimizer, lr_scheduler, scaler,
          criterion, dataloader, num_epochs, device="cuda"):
    losses = []
    for epoch in range(num_epochs):
        diffusion.train()

        epoch_loss = 0.0
        progress_bar = tqdm(dataloader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False)

        for batch_idx, (images, titles) in enumerate(progress_bar):
            images = images.to(device)
            image_titles = [f"A photo of {title}" for title in titles]
            # 50% image_titles là chuỗi rỗng
            image_titles = [title if random.random() < 0.5 else "" for title in image_titles]

            with torch.no_grad():
                latents = vae.encode(images).latent_dist.sample() * 0.18215

            timesteps = torch.randint(
                0, scheduler.total_train_timesteps,
                 (latents.shape[0],), device=device
            )

            noisy_latents, noise = scheduler.add_noise(latents, timesteps)
            time_embeddings = embed_timesteps(timesteps).to(device)
            text_embeddings = text_encoder(image_titles)

            noise_pred = diffusion(noisy_latents, text_embeddings, time_embeddings)

            with autocast(device_type='cuda', dtype=torch.float16,
                          enabled=True, cache_enabled=True):
                loss = criterion(noise_pred, noise)

            optimizer.zero_grad()
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            batch_loss = loss.item()
            epoch_loss += batch_loss

            progress_bar.set_postfix(loss=f"{batch_loss:.5f}",
                                     lr=f"{optimizer.param_groups[0]['lr']:.6f}")

        lr_scheduler.step()
        avg_epoch_loss = epoch_loss / len(dataloader)
        if (epoch + 1) % 10 == 0 or epoch == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}] - Avg Loss: {avg_epoch_loss:.5f}")
        losses.append(avg_epoch_loss)

    print("Training finished!")
    return losses

# %%
EPOCHS = 300

h_dim = 384
n_head = 8

vae = vae.to(device)
diffusion = Diffusion(h_dim, n_head).to(device)
clip = CLIPTextEncoder().to(device)

random_generator = torch.Generator(device='cuda')
noise_scheduler = DDPMScheduler(random_generator)

optimizer = torch.optim.AdamW(diffusion.parameters(), lr=1e-4)
criterion = torch.nn.MSELoss()

lrate_scheduler = lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=EPOCHS, eta_min=1e-5
)
scaler = GradScaler()

def count_parameters(model):
    return sum(p.numel() for p in model.parameters())

vae_params = count_parameters(vae)
diffusion_params = count_parameters(diffusion)
clip_params = count_parameters(clip)

print(f"VAE parameters: {vae_params}")
print(f"Diffusion parameters: {diffusion_params}")
print(f"CLIP parameters: {clip_params}")
print(f"Total parameters: {vae_params + diffusion_params + clip_params}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# VAE parameters: 83653863
# Diffusion parameters: 631718020
# CLIP parameters: 63165952
# Total parameters: 778537835

# %%
losses = train(diffusion, vae, clip, noise_scheduler,
               optimizer, lrate_scheduler, scaler,
               criterion, train_dataloader, EPOCHS, device=device)
# Out:
# Epoch [1/300] - Avg Loss: 0.32515
# Epoch [10/300] - Avg Loss: 0.20479
# Epoch [20/300] - Avg Loss: 0.18856
# Epoch [30/300] - Avg Loss: 0.17721
# Epoch [40/300] - Avg Loss: 0.15972
# Epoch [50/300] - Avg Loss: 0.15967
# Epoch [60/300] - Avg Loss: 0.15253
# Epoch [70/300] - Avg Loss: 0.14532
# Epoch [80/300] - Avg Loss: 0.13478
# Epoch [90/300] - Avg Loss: 0.12788
# Epoch [100/300] - Avg Loss: 0.12866
# Epoch [110/300] - Avg Loss: 0.11850
# Epoch [120/300] - Avg Loss: 0.11680
# Epoch [130/300] - Avg Loss: 0.10949
# Epoch [140/300] - Avg Loss: 0.10621
# Epoch [150/300] - Avg Loss: 0.09746
# Epoch [160/300] - Avg Loss: 0.09584
# Epoch [170/300] - Avg Loss: 0.08785
# Epoch [180/300] - Avg Loss: 0.08699
# Epoch [190/300] - Avg Loss: 0.07966
# Epoch [200/300] - Avg Loss: 0.07957
# Epoch 205/300:  15%|█▌        | 22/145 [00:10<00:59,  2.06it/s, loss=0.08305, lr=0.000031]

# %%
plt.figure(figsize=(16, 8))

plt.plot(losses, label='Loss', color='blue')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')

min_loss = min(losses)
min_loss_epoch = losses.index(min_loss)
plt.scatter(min_loss_epoch, min_loss, color='green', zorder=5)
plt.text(min_loss_epoch,
         min_loss+0.025,
         f'{min_loss:.4f}',
         fontsize=12,
         verticalalignment='center',
         horizontalalignment='center',
         color='green')

plt.legend()
plt.grid()
plt.savefig('training_loss.png')
plt.show()

# %% [markdown]
# # **7. Model Checkpointing**

# %%
torch.save(diffusion.state_dict(), "diffusion_model_emoji.pth")

# %%
h_dim = 384
n_head = 8

VAE_id = "stabilityai/sd-vae-ft-mse"
vae = AutoencoderKL.from_pretrained(VAE_id)
vae.requires_grad_(False)
vae.eval()
vae = vae.to(device)

clip = CLIPTextEncoder().to(device)
clip.eval()

diffusion = Diffusion(h_dim, n_head).to(device)
diffusion.load_state_dict(torch.load("diffusion_model_emoji.pth"))
diffusion.eval()

random_generator = torch.Generator(device='cuda')
noise_scheduler = DDPMScheduler(random_generator)

# %% [markdown]
# # **8. Image Generation**

# %%
LATENTS_WIDTH = WIDTH // 8
LATENTS_HEIGHT = HEIGHT // 8

def generate_image(
    prompt,
    diffusion,
    vae,
    text_encoder,
    scheduler,
    num_inference_steps=100,
    seed=None,
    device='cuda' if torch.cuda.is_available() else 'cpu',
):
    rng_generator = torch.Generator(device=device)
    if seed is None:
        rng_generator.seed()
    else:
        rng_generator.manual_seed(seed)

    prompts = [prompt]
    text_embeddings = text_encoder(prompts).to(device)

    scheduler.set_steps(num_inference_steps)

    latent_shape = (1, 4, LATENTS_HEIGHT, LATENTS_WIDTH)

    noisy_latents = torch.randn(
        latent_shape, generator=rng_generator, device=device)
    timesteps = scheduler.schedule_timesteps

    for t in tqdm(timesteps):
        latent_model_input = noisy_latents

        time_embedding = embed_a_timestep(t).to(device)

        with torch.no_grad():
            noise_pred = diffusion(
                latent_model_input,
                text_embeddings,
                time_embedding
            )
        noisy_latents = scheduler.step(
            t,
            noisy_latents,
            noise_pred
        )

    final_latents = noisy_latents / 0.18215

    with torch.no_grad():
        decoded_image_tensor = vae.decode(final_latents).sample

    image_output = rescale(decoded_image_tensor, (-1, 1), (0, 255), clamp=True)
    image_output = image_output.permute(0, 2, 3, 1).to("cpu", torch.uint8).numpy()
    return image_output[0]

# %%
user_inputs = prompts = [
    "a happy blob emoji with sparkling eyes open mouth showing tongue, green skin, floating, purple background",
    "an angry blob emoji with narrowed eyes frowning mouth, orange skin, wearing a party hat, white background",
    "a confused blob emoji with wide eyes slightly open mouth, yellow skin, pointing at his head and wearing a star-shaped crown, dark blue background",
    "a sad blob emoji with droopy eyes frowning mouth, green skin, waving hand and wearing red pom-poms, white background",
    "a grumpy blob emoji with half-closed eyes frowning mouth, purple skin, wielding a large knife, red background",
    "a happy blob emoji with teary eyes smiling mouth, pink skin, wearing a sombrero, white background",
    "a devilish blob emoji with red eyes wide open mouth showing tongue, red skin, wearing horns and hugging a teddy bear, warm background with a fireplace and autumn leaves",
    "a cozy blob emoji with half-closed eyes slightly open mouth, orange skin, holding a steaming cup of coffee and making a fist, warm background with a fireplace and autumn leaves",
    "a surprised blob emoji with wide eyes open mouth, yellow skin, wearing a purple hoodie and sitting on its hind legs, blue background",
]

fig, axes = plt.subplots(3, 3, figsize=(3, 3))
axes = axes.flatten()
for i, user_input in enumerate(user_inputs[:9]):
    prompt = f"A photo of {user_input.lower()}"
    img = generate_image(prompt, diffusion, vae, clip, noise_scheduler, num_inference_steps=100)
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 16.50it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.54it/s]
# 100%|██████████| 100/100 [00:05<00:00, 17.52it/s]
# 100%|██████████| 100/100 [00:05<00:00, 17.67it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.69it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.04it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.90it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.98it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.92it/s]

# %%
user_inputs = [
    "a sad blob emoji with droopy eyes, frowning mouth, brown skin, wearing a party hat, red background",
    "a sleepy blob emoji with closed eyes, frowning mouth, green skin, sitting on its hind legs, white background",
    "a curious blob emoji with half-closed eyes, slightly open mouth, yellow skin, pointing finger upwards, dark blue background",
    "a happy blob emoji with bright blue eyes, wide open mouth, green skin, hanging from a string, white background",
    "a confused blob emoji with wide eyes, slightly open mouth, yellow skin, wearing a red bow tie, white background",
    "a grumpy blob emoji with half-closed eyes, wide open mouth showing teeth, yellow skin, light blue background with red hearts around",
    "a happy blob emoji with wide open eyes, smiling mouth, pink skin, sitting on a blue ribbon, white background",
    "a laughing blob emoji with closed eyes, wide open mouth, orange skin, holding a thermometer, white background",
    "a cool blob emoji with sunglasses, smiling mouth, pink skin, wearing horns, purple background",
]

fig, axes = plt.subplots(3, 3, figsize=(3, 3))
axes = axes.flatten()
for i, user_input in enumerate(user_inputs[:9]):
    prompt = f"A photo of {user_input.lower()}"
    img = generate_image(prompt, diffusion, vae, clip, noise_scheduler, num_inference_steps=100)
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.26it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.35it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.78it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.79it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.96it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.71it/s]
# 100%|██████████| 100/100 [00:04<00:00, 21.31it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.25it/s]
# 100%|██████████| 100/100 [00:04<00:00, 21.32it/s]

# %%
user_inputs = [
    "a sleepy blob emoji with closed eyes, smiling mouth, green skin, holding a teddy bear, purple background",
    "an angry blob emoji with wide open eyes, showing teeth, gray skin, wearing a sombrero, red background",
    "a confused blob emoji with wide eyes, slightly open mouth, pink skin, holding a sign that says SIMP, dark blue background",
    "a grumpy blob emoji with half-closed eyes, frowning mouth, green skin, eating popcorn while wearing a sleeping mask, white background",
    "a heart-eyed blob emoji with heart-shaped eyes, open mouth showing tongue, white skin, making a fist, light blue background with red hearts",
    "a sad blob emoji with teary eyes, frowning mouth, yellow skin, wearing sunglasses, black background",
    "a cheerful blob emoji with bright eyes, big smile, green skin, sitting on a swing and wearing a rainbow hat, white background",
    "a curious blob emoji with large, round eyes, slightly open mouth, light brown skin, floating and wearing a blue shirt, purple background",
    "a menacing blob emoji with narrowed eyes, open mouth showing teeth, green skin, hugging a person while wearing a party hat, blue background",
]

fig, axes = plt.subplots(3, 3, figsize=(3, 3))
axes = axes.flatten()
for i, user_input in enumerate(user_inputs[:9]):
    prompt = f"A photo of {user_input.lower()}"
    img = generate_image(prompt, diffusion, vae, clip, noise_scheduler, num_inference_steps=100)
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 20.98it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.67it/s]
# 100%|██████████| 100/100 [00:04<00:00, 21.31it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.33it/s]
# 100%|██████████| 100/100 [00:04<00:00, 21.34it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.91it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.65it/s]
# 100%|██████████| 100/100 [00:04<00:00, 21.35it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.35it/s]

# %%
user_inputs = [
    "a grumpy blob emoji with half-closed eyes, smiling mouth, green skin, wearing a sombrero, red background",
    "a happy blob emoji with wide eyes, frowning mouth, red skin, pointing finger upwards, black background",
    "a sad blob emoji with teary eyes, wide open mouth showing tongue, orange skin, wearing a party hat, purple background",
    "a confused blob emoji with bright blue eyes, slightly open mouth, yellow skin, holding a large knife, white background",
    "a sleepy blob emoji with closed eyes, big smile, pink skin, wearing a rainbow hat, dark blue background",
    "an angry blob emoji with narrowed eyes, licking lips, white skin, sitting on a swing, warm background with fireplace",
    "a cool blob emoji with sunglasses, frowning mouth, purple skin, eating popcorn, light blue background with hearts",
    "a devilish blob emoji with red eyes, smiling mouth, brown skin, holding a steaming cup of coffee, white background",
    "a curious blob emoji with large round eyes, open mouth showing teeth, gray skin, hugging a teddy bear, red background",
]

fig, axes = plt.subplots(3, 3, figsize=(3, 3))
axes = axes.flatten()
for i, user_input in enumerate(user_inputs[:9]):
    prompt = f"A photo of {user_input.lower()}"
    img = generate_image(prompt, diffusion, vae, clip, noise_scheduler, num_inference_steps=100)
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.62it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.74it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.89it/s]
# 100%|██████████| 100/100 [00:04<00:00, 21.41it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.31it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.55it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.74it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.94it/s]
# 100%|██████████| 100/100 [00:04<00:00, 21.44it/s]
